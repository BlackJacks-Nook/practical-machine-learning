# %% [markdown]
# # Setting Up Programming Environment

# %% [markdown]
# <div class='alert alert-info'>
#
# :::{objectives}
# In this episode, we provide comprehensive, step-by-step instructions for setting up programming environments and running tutorials, whether you choose to work on your personal computer or through [Google Colab](https://colab.research.google.com/) platform.
# :::
# </div>

# %% [markdown]
# ## 1. Using Personal Computer

# %% [markdown]
# Below are detailed instructions for installing required packages and their dependencies on a local computer or server.

# %% [markdown]
# ### 1.1 Install miniforge

# %% [markdown]
# If you already have a preferred way to manage Python versions and libraries, you can stick to that. Otherwise, we recommend you to install Python3 and all required libraries using [**Miniforge**](https://conda-forge.org/download/), a free minimal installer for package, dependency, and environment manager [**Conda**](https://docs.conda.io/en/latest/index.html).
# - Please follow [installation instructions](https://conda-forge.org/download/) to install Miniforge.
# - After installation, verify that Conda is installed correctly by running:
#     ```console
#     $ conda --version
#     # Example output: conda 24.11.2
#     ```

# %% [markdown]
# ### 1.2 Configure programming environment

# %% [markdown]
# With Conda installed, open **Anaconda Prompt terminal**, and run command below to install required packages and depenencies (except PyTorch).
# ```console
# $ conda env create -y --file=https://raw.githubusercontent.com/ENCCS/practical-machine-learning/main/content/env/environment.yml
# ```
#
# This creates a new environment called `practical_machine_learning`, and we activate it before installing PyTorch library.
# ```console
# $ conda activate practical_machine_learning
# $ conda install -y pytorch torchvision torchaudio torchtext cpuonly -c pytorch
# ```

# %% [markdown]
# <div class="alert alert-warning">
#
# :::{warning}
# Remember to activate your programming environment each time before running code examples. This ensures that correct Python version and all required dependencies are available. If you forget to activate it, you may encounter errors or missing packages.
# :::
# </div>

# %% [markdown]
# ### 1.3 Validate programming environment

# %% [markdown]
# Once programming environment is fully set up, open a new **Anaconda Prompt terminal** (just as you should do each time before running code examples), activate programming environment, and launch JupyterLab by running command below.
# ```console
# $ conda activate practical_machine_learning
# $ jupyter lab
# ```
#
# This will start a Jupyter server and automatically open JupyterLab interface in your web browser.
#
# To verify that all required packages are properly installed, follow these steps:
# - Open JupyterLab (see instructions above).
# - Create a new Jupyter Notebook by selecting **File** → **New** → **Notebook**.
# - Copy code examples listed below into a cell of notebook.
# - Run cell (press **Shift + Enter** or click the **Run** button).
#
# ```python
# import numpy;      print('Numpy version: ',            numpy.__version__)
# import pandas;     print('Pandas version: ',           pandas.__version__)
# import scipy;      print('Scipy version: ',            scipy.__version__)
# import matplotlib; print('Matplotlib version: ',       matplotlib.__version__)
# import seaborn;    print('Seaborn version: ',          seaborn.__version__)
# import sklearn;    print('Scikit-learn version: ',     sklearn.__version__)
# import keras;      print('Keras version: ',            keras.__version__)
# import tensorflow; print('Tensorflow version: ',       tensorflow.__version__)
# import torch;      print('Pytorch version: ',          torch.__version__)
# import umap;       print('Umap-learn version: ',       umap.__version__)
# import notebook;   print('Jupyter Notebook version: ', notebook.__version__)
# ```
#
# You should see similar outputs listed in figure below. The exact package versions may vary depending on when you installed them. If code runs without errors, it means that all packages are correctly installed and your programming environment is ready to use.

# %%
from IPython.display import display, Image
display(Image("./verification-programming-environment.png", width=1024))

# %% [markdown]
# <div class="alert alert-warning">
#
# :::{warning}
#
# For Windows OS users, you might encounter an error (`ImportError: DLL load failed while importing _C: The specified procedure could not be found`) as described below.
#
# It is a very common Windows-specific PyTorch issue, and it means that underlying C++/CUDA DLLs that torch depends on could not be loaded correctly. You should reinstall correct matching build via command below.
# ```console
# $ conda install -y pytorch torchvision torchaudio torchtext cpuonly -c pytorch
# ```
# :::
# </div>

# %%
display(Image("./pytorch-error.png", width=1024))

# %% [markdown]
# <div class="alert alert-success">
#
# :::{info}
# If you are using VS Code, you can select installed `practical_machine_learning` programming environment as follows:
# - Open your project folder in VS Code.
# - In upper-right corner of editor window (when working with a Python file or Jupyter Notebook), click on **Select Kernel**.
# - From list of **Python Environments**, locate and choose `practical_machine_learning` environment (which you have installed earlier).
# - Once selected, VS Code will use this environment for running Python code and Jupyter Notebooks, ensuring that all required packages are available.
# :::
# </div>

# %% [markdown]
# ### 1.4 Setting up PyTorch with GPU support (optional)

# %% [markdown]
# **For Windows OS users**, if your computer has a GPU card, you can install PyTorch with GPU support. Below are step-by-step instructions to update `practical_machine_learning` programming environment.
#
# <mark>First</mark> check your CUDA version. Open a terminal (Linux/macOS) or PowerShell (Windows) and run:
# ```console
# $ nvcc --version
# ```
# If `nvcc` is not in your PATH, you can instead run `nvidia-smi`.
# ```console
# $ nvidia-smi
# ```
#
# Here is output from my windows machine:

# %%
display(Image("./test-cuda-compiler-driver.png", width=1024))

# %% [markdown]
# <mark>Second</mark>, remove any CPU-only versions of PyTorch that may have been installed (*i.e.*, those coming from Conda’s defaults or conda-forge channels), and then install an older, CUDA-compatible version of PyTorch directly using `pip`.
# Here `cu121` indicates CUDA version (12.1) that PyTorch build was compiled with.
#
# ```console
# $ conda activate practical_machine_learning
# $ conda remove pytorch torchvision torchaudio torchtext
# $ pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --index-url https://download.pytorch.org/whl/cu121
# ```

# %% [markdown]
# <mark>Third</mark>, verify your installation in a Jupyter Notebook. Run following command and ensure it returns `True` for `torch.cuda.is_available()`.
#
# ```python
# import torch
# print(torch.__version__)               # 2.4.0+cu121
# print(torch.cuda.is_available())       # True
# print(torch.cuda.get_device_name(0))   # NVIDIA GeForce GT 1030
# ```

# %% [markdown]
# ## 2. Using Google Colab

# %% [markdown]
# You can also run all code examples in tutorials using [Google Colab](https://colab.research.google.com/), a free cloud-based platform that provides Jupyter Notebook environments with preinstalled ML libraries.

# %% [markdown]
# ### 2.1 Upload Jupyter NBs from GitHub to Google Drive (method 1)

# %% [markdown]
# You can run tutorials directly on [Google Colab](https://colab.research.google.com/) by following steps:
# - Go to [Google Colab](https://colab.research.google.com/) and sign in with your Google account.
# - In top menu, click **File → upload notebook**.
# - Select **GitHub** tab, search for *enccs*, and then choose repository `ENCCS/practical-machine-learning` to open desired Jupyter Notebooks.

# %%
display(Image("./google-colab-upload-jupyter-notebooks-from-github.png", width=1024))

# %% [markdown]
# ### 2.1 Upload Jupyter NBs from local computer (method 2)

# %% [markdown]
# <mark>First</mark> download all Jupyter Notebooks from website
# - You can open each Jupyter NB (usually with `.ipynb` extension) from [HERE](https://github.com/ENCCS/practical-machine-learning/tree/main/content/jupyter-notebooks), and then select **Download raw file** to save it locally.
# - Alternatively, you can download entire repository at [HERE](https://github.com/ENCCS/practical-machine-learning/tree/main) by clicking green `<> Code` button and choosing **Download ZIP** file.
#     - After unzipping downloaded ZIP file, you will find all Jupyter NBs in directory **practical-machine-learning-main/content/jupyter-notebooks**.
#
# <mark>Second</mark> upload Jupyter NBs to Google Drive
# - Sign in to your [Google Drive](https://workspace.google.com/intl/en-US/products/drive/), then upload downloaded Jupyter NBs to a convenient folder.
# - You can simply drag and drop files directly into Google Drive or use option **New → File upload**.
#
# <mark>Third</mark> launch Jupyter NB in Google Colab
# - Once uploaded, right-click Jupyter NBs file in Google Drive and select **Open with → Google Colaboratory**.
# - This will launch notebook in Google Colab, where you can view, edit, and run code cells interactively.

# %% [markdown]
# ### 2.2 Connect to a hosted runtime

# %% [markdown]
# In Google Colab, go to top-right corner and click **Connect** to link your notebook to a Google-hosted runtime environment.
#
# If you need GPU or TPU acceleration, select **Runtime → Change runtime type**, then choose desired hardware accelerator.

# %% [markdown]
# ### 2.3 Run tutorials

# %% [markdown]
# After connecting, follow instructions inside Jupyter NBs.
#
# You can run each cell individually by pressing **Shift** + **Enter**, or execute entire notebook using **Runtime → Run all**.

# %% [markdown]
# ## 3. Using Berzelius Cluster

# %% [markdown]
# Please open a terminal and follow these steps.

# %% [markdown]
# ### 3.1 Connect to Berzelius and copy Jupyter notebooks to your home directory

# %% [markdown]
# ```console
# $ ssh <username>@berzelius.nsc.liu.se
#
# $ cp -a /proj/berzelius-training/practical_machine_learning ~/
# $ cd ~/practical_machine_learning
# ```

# %% [markdown]
# ### 3.2 Load Miniforge module and create mamba environment

# %% [markdown]
# ```console
# $ module load Miniforge3
#
# $ mamba env create --yes -f https://gitlab.liu.se/NSC/berzelius-training/-/raw/b380ede41101cba983430821fb0d65382859c448/practical-intro-to-machine-learning/content/env/environment.yml
# ```

# %% [markdown]
# ### 3.3 Start an interactive session with one GPU

# %% [markdown]
# ```console
# $ interactive --gpus 1 -t 180 -A berzelius-2025-325 --reservation=bt-berzelius-training
# ```
# - Use the `-t` flag to specify the walltime (in minutes). In this example, `-t 180` requests 3 hours. We have revered two GPU nodes (16 GPUs) for this workshop from 09:00 to 12:30.
# - After the workshop, you will retain access to Berzelius for 7 days. After that period, you will be removed from the `berzelius-training` project.

# %% [markdown]
# ### 3.4 Activate environment and start Jupyter notebook

# %% [markdown]
# ```console
# $ mamba activate practical_machine_learning
#
# $ jupyter-lab --no-browser --ip=node004 --port=9988
# ```
# - Use the `--ip` flag to specify the compute node. It should be either node004 or node054.
# - The port `9988` is arbitrary. If it's already in use, try another (e.g., 9989, 9990, etc.).

# %% [markdown]
# You will see output similar to the following:
#
# ```console
# [I 12:36:50.243 NotebookApp] Jupyter Notebook 6.5.2 is running at:
# [I 12:36:50.243 NotebookApp] http://node021:9988/?token=xxxx
# [I 12:36:50.243 NotebookApp]  or http://127.0.0.1:9988/?token=xxxx
# [I 12:36:50.243 NotebookApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [C 12:36:50.256 NotebookApp]
#
#     To access the notebook, open this file in a browser:
#         file:///home/username/.local/share/jupyter/runtime/nbserver-511678-open.html
#     Or copy and paste one of these URLs:
#         http://node021:9988/?token=xxxx
#      or http://127.0.0.1:9988/?token=xxxx
# ```

# %% [markdown]
# ### 3.5 Create the SSH tunnel from your Local Computer

# %% [markdown]
# Open a new terminal on your local computer (not on Berzelius), and run the following command:
#
# ```console
# $ ssh -N -L localhost:9988:node005:9988 <username>@berzelius1.nsc.liu.se
# ```
#
# This forwards port 9988 on your local machine to the compute node's port.

# %% [markdown]
# ### 3.6 Open Jupyter Notebook in your Browser
#
# Paste the URL with the **token** (copied from the Jupyter output) into your browser on your local machine:
#
# ```console
# http://localhost:9988/?token=xxxx
# ```
#
# In the Jupyter interface, navigate to the ``practical_machine_learning`` directory in your home folder and open the notebook file you copied earlier.
#
# Congratulations! You’ve now set up a Jupyter Notebook on Berzelius and can start working interactively.
